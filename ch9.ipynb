# %%
import csv

f = open('card.csv')
print(f)
# Out:
# <_io.TextIOWrapper name='card.csv' mode='r' encoding='UTF-8'>

# %%
f = open('card.csv', encoding='utf8')
print(f)
# Out:
# <_io.TextIOWrapper name='card.csv' mode='r' encoding='utf8'>

# %%
#아직 2차원 리스트 형식이 아님
f = open('card.csv', encoding='utf8')
data = csv.reader(f)
print(data)

# %%
#list로 바꿔주기
#\나오는 문제는 인코딩 문제 utf-8-sig 이렇게 수정하면 됨
f = open('card.csv', encoding='utf-8-sig')
data = csv.reader(f)
data = list(data)
print(data)
# Out:
# [['이용일시', '승인번호', '본인구분', '브랜드', '이용카드', '가맹점명', '이용금액', '이용구분', '매입상태'], ['2019-10-12 9:13', '1972753', '본', 'S&', '185', '네이버파이낸셜(주)', '546800', '일시불(A)', '부분취소'], ['2019-10-12 11:56', '3399357', '본', 'S&', '185', 'GS  샵', '60440', '일시불(A)', '전표매입'], ['2019-10-13 9:16', '12621902', '본', 'S&', '185', 'G마켓', '91520', 'P(A)', '전표매입'], ['2019-10-14 1:32', '20726947', '본', 'S&', '185', '11번가', '89810', '일시불(A)', '전표매입'], ['2019-10-14 7:06', '21234320', '본', 'S&', '185', '네이버파이낸셜(주)', '33600', '일시불(A)', '전표매입'], ['2019-10-15 23:32', '42229559', '본', 'S&', '185', '네이버파이낸셜(주)', '309600', '일시불(A)', '부분취소'], ['2019-10-16 8:00', '43433092', '본', 'S&', '185', 'SSG.COM', '61983', '일시불(A)', '부분취소'], ['2019-10-16 16:04', '48341209', '본', 'S&', '185', '(주)에이랜드 타임스퀘어', '31600', '일시불', '전표매입'], ['2019-10-17 1:13', '3495922', '본', 'S&', '185', '(주)어패럴컴퍼니', '97000', '일시불(A)', '부분취소'], ['2019-10-17 20:19', '12252560', '본', 'S&', '185', '(주)곱', '96000', '일시불', '전표매입'], ['2019-10-17 20:28', '12336385', '
# ...

# %%
f = open('card.csv', encoding='utf8')
data = csv.reader(f)
#표의 헤더 제거하기
next(data)
data = list(data)
print(data)
#데이터크기가 크면 next를 이용해서 헤더를 날리기 보다는 헤더와 그 이후의 리스트를 각각의 변수에 저장
# Out:
# [['2019-10-12 9:13', '1972753', '본', 'S&', '185', '네이버파이낸셜(주)', '546800', '일시불(A)', '부분취소'], ['2019-10-12 11:56', '3399357', '본', 'S&', '185', 'GS  샵', '60440', '일시불(A)', '전표매입'], ['2019-10-13 9:16', '12621902', '본', 'S&', '185', 'G마켓', '91520', 'P(A)', '전표매입'], ['2019-10-14 1:32', '20726947', '본', 'S&', '185', '11번가', '89810', '일시불(A)', '전표매입'], ['2019-10-14 7:06', '21234320', '본', 'S&', '185', '네이버파이낸셜(주)', '33600', '일시불(A)', '전표매입'], ['2019-10-15 23:32', '42229559', '본', 'S&', '185', '네이버파이낸셜(주)', '309600', '일시불(A)', '부분취소'], ['2019-10-16 8:00', '43433092', '본', 'S&', '185', 'SSG.COM', '61983', '일시불(A)', '부분취소'], ['2019-10-16 16:04', '48341209', '본', 'S&', '185', '(주)에이랜드 타임스퀘어', '31600', '일시불', '전표매입'], ['2019-10-17 1:13', '3495922', '본', 'S&', '185', '(주)어패럴컴퍼니', '97000', '일시불(A)', '부분취소'], ['2019-10-17 20:19', '12252560', '본', 'S&', '185', '(주)곱', '96000', '일시불', '전표매입'], ['2019-10-17 20:28', '12336385', '본', 'S&', '185', '카카오택시(선승인)', '4200', '일시불', '승인취소'], ['2019-10-17 20:35
# ...

# %%
print(len(data))
# Out:
# 236

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
print(data[0])
# Out:
# ['2019-10-12 9:13', '1972753', '본', 'S&', '185', '네이버파이낸셜(주)', '546800', '일시불(A)', '부분취소']

# %%
print(data[:3])
# Out:
# [['2019-10-12 9:13', '1972753', '본', 'S&', '185', '네이버파이낸셜(주)', '546800', '일시불(A)', '부분취소'], ['2019-10-12 11:56', '3399357', '본', 'S&', '185', 'GS  샵', '60440', '일시불(A)', '전표매입'], ['2019-10-13 9:16', '12621902', '본', 'S&', '185', 'G마켓', '91520', 'P(A)', '전표매입']]

# %%
print(data[0][6])
# Out:
# 546800

# %%
print(data[0][5], data[0][6])
# Out:
# 네이버파이낸셜(주) 546800

# %%
print(data[0][0], data[0][5], data[0][6])
# Out:
# 2019-10-12 9:13 네이버파이낸셜(주) 546800

# %%
for row in data:
    print(row[0], row[5], row[6])
# Out:
# 2019-10-13 9:16 G마켓 91520
# 2019-10-14 1:32 11번가 89810
# 2019-10-14 7:06 네이버파이낸셜(주) 33600
# 2019-10-15 23:32 네이버파이낸셜(주) 309600
# 2019-10-16 8:00 SSG.COM 61983
# 2019-10-16 16:04 (주)에이랜드 타임스퀘어 31600
# 2019-10-17 1:13 (주)어패럴컴퍼니 97000
# 2019-10-17 20:19 (주)곱 96000
# 2019-10-17 20:28 카카오택시(선승인) 4200
# 2019-10-17 20:35 카카오페이(택시) 4200
# 2019-10-17 22:43 포도당 75000
# 2019-10-18 9:23 에뛰드 26410
# 2019-10-18 13:07 네이버파이낸셜(주) 12500
# 2019-10-18 15:48 미니스톱신촌점 1300
# 2019-10-19 20:51 (주)우아한형제들 19000
# 2019-10-20 11:05 프렌트립 55995
# 2019-10-20 19:41 네이버파이낸셜(주) 118000
# 2019-10-20 20:41 네이버파이낸셜(주) 269000
# 2019-10-21 8:02 ZARA 251000
# 2019-10-21 9:01 네이버파이낸셜(주) 75600
# 2019-10-21 19:39 스패뉴시청지점 61800
# 2019-10-22 0:20 네이버파이낸셜(주) 40900
# 2019-10-22 19:13 티머니 개인택시 4400
# 2019-10-23 14:33 스타벅스코리아 10000
# 2019-10-23 17:11 (주)우아한형제들 21400
# 2019-10-23 17:15 (주)우아한형제들 63000
# 2019-10-24 8:14 전화결제 207000
# 2019-10-24 16:02 케이데코(K Deco) 48000
# 2019-10-24 17:49 씨제이올리브영(주)합정메세나폴 23200
# ...

# %%
header = data[0]  # 첫 번째 행을 헤더로 저장
data = data[1:]  # 나머지를 데이터로 저장

print("헤더:", header)
# Out:
# 헤더: ['2019-10-12 11:56', '3399357', '본', 'S&', '185', 'GS  샵', '60440', '일시불(A)', '전표매입']

# %%
print("데이터:", data)
# Out:
# 데이터: [['2019-10-13 9:16', '12621902', '본', 'S&', '185', 'G마켓', '91520', 'P(A)', '전표매입'], ['2019-10-14 1:32', '20726947', '본', 'S&', '185', '11번가', '89810', '일시불(A)', '전표매입'], ['2019-10-14 7:06', '21234320', '본', 'S&', '185', '네이버파이낸셜(주)', '33600', '일시불(A)', '전표매입'], ['2019-10-15 23:32', '42229559', '본', 'S&', '185', '네이버파이낸셜(주)', '309600', '일시불(A)', '부분취소'], ['2019-10-16 8:00', '43433092', '본', 'S&', '185', 'SSG.COM', '61983', '일시불(A)', '부분취소'], ['2019-10-16 16:04', '48341209', '본', 'S&', '185', '(주)에이랜드 타임스퀘어', '31600', '일시불', '전표매입'], ['2019-10-17 1:13', '3495922', '본', 'S&', '185', '(주)어패럴컴퍼니', '97000', '일시불(A)', '부분취소'], ['2019-10-17 20:19', '12252560', '본', 'S&', '185', '(주)곱', '96000', '일시불', '전표매입'], ['2019-10-17 20:28', '12336385', '본', 'S&', '185', '카카오택시(선승인)', '4200', '일시불', '승인취소'], ['2019-10-17 20:35', '12421511', '본', 'S&', '185', '카카오페이(택시)', '4200', '일시불', '전표매입'], ['2019-10-17 22:43', '13427539', '본', 'S&', '185', '포도당', '75000', '일시불', '전표매입'], ['2019-10-18 9:23', '
# ...

# %%
for row in data:
    print(row[0], row[5], type(row[6]))
# Out:
# 2019-10-13 9:16 G마켓 <class 'str'>
# 2019-10-14 1:32 11번가 <class 'str'>
# 2019-10-14 7:06 네이버파이낸셜(주) <class 'str'>
# 2019-10-15 23:32 네이버파이낸셜(주) <class 'str'>
# 2019-10-16 8:00 SSG.COM <class 'str'>
# 2019-10-16 16:04 (주)에이랜드 타임스퀘어 <class 'str'>
# 2019-10-17 1:13 (주)어패럴컴퍼니 <class 'str'>
# 2019-10-17 20:19 (주)곱 <class 'str'>
# 2019-10-17 20:28 카카오택시(선승인) <class 'str'>
# 2019-10-17 20:35 카카오페이(택시) <class 'str'>
# 2019-10-17 22:43 포도당 <class 'str'>
# 2019-10-18 9:23 에뛰드 <class 'str'>
# 2019-10-18 13:07 네이버파이낸셜(주) <class 'str'>
# 2019-10-18 15:48 미니스톱신촌점 <class 'str'>
# 2019-10-19 20:51 (주)우아한형제들 <class 'str'>
# 2019-10-20 11:05 프렌트립 <class 'str'>
# 2019-10-20 19:41 네이버파이낸셜(주) <class 'str'>
# 2019-10-20 20:41 네이버파이낸셜(주) <class 'str'>
# 2019-10-21 8:02 ZARA <class 'str'>
# 2019-10-21 9:01 네이버파이낸셜(주) <class 'str'>
# 2019-10-21 19:39 스패뉴시청지점 <class 'str'>
# 2019-10-22 0:20 네이버파이낸셜(주) <class 'str'>
# 2019-10-22 19:13 티머니 개인택시 <class 'str'>
# 2019-10-23 14:33 스타벅스코리아 <class 'str'>
# ...

# %%
for row in data:
    payment = int(row[6])
    print(payment, type(payment))
# Out:
# 91520 <class 'int'>
# 89810 <class 'int'>
# 33600 <class 'int'>
# 309600 <class 'int'>
# 61983 <class 'int'>
# 31600 <class 'int'>
# 97000 <class 'int'>
# 96000 <class 'int'>
# 4200 <class 'int'>
# 4200 <class 'int'>
# 75000 <class 'int'>
# 26410 <class 'int'>
# 12500 <class 'int'>
# 1300 <class 'int'>
# 19000 <class 'int'>
# 55995 <class 'int'>
# 118000 <class 'int'>
# 269000 <class 'int'>
# 251000 <class 'int'>
# 75600 <class 'int'>
# 61800 <class 'int'>
# 40900 <class 'int'>
# 4400 <class 'int'>
# 10000 <class 'int'>
# 21400 <class 'int'>
# 63000 <class 'int'>
# 207000 <class 'int'>
# 48000 <class 'int'>
# 23200 <class 'int'>
# 23100 <class 'int'>
# 10000 <class 'int'>
# 50000 <class 'int'>
# 5300 <class 'int'>
# 3990 <class 'int'>
# 11900 <class 'int'>
# 112845 <class 'int'>
# 161598 <class 'int'>
# 16241 <class 'int'>
# 19000 <class 'int'>
# 28500 <class 'int'>
# 4000 <class 'int'>
# 7000 <class 'int'>
# 66046 <class 'int'>
# 139500 <class 'int'>
# 86300 <class 'int'>
# ...

# %%
for row in data:
    payment = int(row[6])
    store = row[6]
    print(store, '에서', payment, '원 결제')
# Out:
# 91520 에서 91520 원 결제
# 89810 에서 89810 원 결제
# 33600 에서 33600 원 결제
# 309600 에서 309600 원 결제
# 61983 에서 61983 원 결제
# 31600 에서 31600 원 결제
# 97000 에서 97000 원 결제
# 96000 에서 96000 원 결제
# 4200 에서 4200 원 결제
# 4200 에서 4200 원 결제
# 75000 에서 75000 원 결제
# 26410 에서 26410 원 결제
# 12500 에서 12500 원 결제
# 1300 에서 1300 원 결제
# 19000 에서 19000 원 결제
# 55995 에서 55995 원 결제
# 118000 에서 118000 원 결제
# 269000 에서 269000 원 결제
# 251000 에서 251000 원 결제
# 75600 에서 75600 원 결제
# 61800 에서 61800 원 결제
# 40900 에서 40900 원 결제
# 4400 에서 4400 원 결제
# 10000 에서 10000 원 결제
# 21400 에서 21400 원 결제
# 63000 에서 63000 원 결제
# 207000 에서 207000 원 결제
# 48000 에서 48000 원 결제
# 23200 에서 23200 원 결제
# 23100 에서 23100 원 결제
# 10000 에서 10000 원 결제
# 50000 에서 50000 원 결제
# 5300 에서 5300 원 결제
# 3990 에서 3990 원 결제
# 11900 에서 11900 원 결제
# 112845 에서 112845 원 결제
# 161598 에서 161598 원 결제
# 16241 에서 16241 원 결제
# 19000 에서 19000 원 결제
# 28500 에서 28500 원 결제
# 4000 에서 4000 원 결제
# 7000 에서 7000 원 결제
# 66046 에서 66046 원 결제
# 139500 에서 139500 원 결제
# 86300 에서 86300 원 결제
# ...

# %%
for row in data:
    date = row[0].split()[0]
    payment = int(row[6])
    store = row[5]
    print(date, store, '에서', payment, '원 결제')
# Out:
# 2019-10-13 G마켓 에서 91520 원 결제
# 2019-10-14 11번가 에서 89810 원 결제
# 2019-10-14 네이버파이낸셜(주) 에서 33600 원 결제
# 2019-10-15 네이버파이낸셜(주) 에서 309600 원 결제
# 2019-10-16 SSG.COM 에서 61983 원 결제
# 2019-10-16 (주)에이랜드 타임스퀘어 에서 31600 원 결제
# 2019-10-17 (주)어패럴컴퍼니 에서 97000 원 결제
# 2019-10-17 (주)곱 에서 96000 원 결제
# 2019-10-17 카카오택시(선승인) 에서 4200 원 결제
# 2019-10-17 카카오페이(택시) 에서 4200 원 결제
# 2019-10-17 포도당 에서 75000 원 결제
# 2019-10-18 에뛰드 에서 26410 원 결제
# 2019-10-18 네이버파이낸셜(주) 에서 12500 원 결제
# 2019-10-18 미니스톱신촌점 에서 1300 원 결제
# 2019-10-19 (주)우아한형제들 에서 19000 원 결제
# 2019-10-20 프렌트립 에서 55995 원 결제
# 2019-10-20 네이버파이낸셜(주) 에서 118000 원 결제
# 2019-10-20 네이버파이낸셜(주) 에서 269000 원 결제
# 2019-10-21 ZARA 에서 251000 원 결제
# 2019-10-21 네이버파이낸셜(주) 에서 75600 원 결제
# 2019-10-21 스패뉴시청지점 에서 61800 원 결제
# 2019-10-22 네이버파이낸셜(주) 에서 40900 원 결제
# 2019-10-22 티머니 개인택시 에서 4400 원 결제
# 2019-10-23 스타벅스코리아 에서 10000 원 결제
# 2019-10-23 (주)우아한형제들 에서 21400 원 결제
# 2019-10-23 (주)우아한형제들 에서 63000 원 결제
# 2019-10-24 전화결제 에서 207000 원 결제
# 2019-10-24 케이데코(K Deco) 에서 48000 원 결제
# ...

# %%
for row in data:
    if row[-1] == '전표매입':
        print('구매확정')
    else:
        print('구매취소')
# Out:
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매취소
# 구매확정
# 구매취소
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매취소
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매취소
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매취소
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# 구매확정
# ...

# %%
spend = 0
for row in data:
    if row[-1] == '전표매입':
       spend += int(row[-3])
print(spend)
# Out:
# 8113588

# %%
spend = 0
for row in data:
    if row[-1] == '전표매입':
       spend += int(row[-3])

# 1. 숫자를 문자열로 변환하면서 뒤집기
spend_str = str(spend)[::-1]
parts = []

# 2. 3자리씩 나누고 ","으로 연결하기
for i in range(0, len(spend_str), 3):
    part = spend_str[i:i+3]
    parts.append(part)

    spend_with_comma = ",".join(parts)[::-1]

# 3. 다시 뒤집기
print(spend_with_comma)
# Out:
# 8,113,588

# %%
import matplotlib.pyplot as plt

s_mon = [0, 0, 0]
for row in data:
    if row[-1] == '전표매입':
        mon, paymenet = row[0].split("-")[1], int(row[-3])
        idx = int(mon) - 10
        s_mon[idx] += payment
print(s_mon)

plt.rc('font', family='Nanum Gothic')
plt.title('10~12월 지출현황')
plt.bar(['10월', '11월', '12월'], s_mon, color='royalblue')  
plt.show()
# Out:
# [698880, 1497600, 1181440]

# %%
taxi = [0, 0, 0]
deli = [0, 0, 0]

for row in data:
    if row[-1] == '전표매입' and '택시' in row[-4]: 
        mon, payment = int(row[0].split("-")[1]), int(row[-3])
        idx = int(mon) - 10
        taxi[idx] += payment
print(taxi)

for row in data:
    if row[-1] == '전표매입' and '(주)우아한형제들' in row[-4]: 
        mon, payment = int(row[0].split("-")[1]), int(row[-3])
        idx = int(mon) - 10
        deli[idx] += payment
print(deli)

plt.rc('font', family='Nanum Gothic')
plt.title('10~12월 택시비 지출현황')
plt.plot(['10월', '11월', '12월'], taxi, color='crimson', label='택시비 지출액')
plt.plot(['10월', '11월', '12월'], deli, color='indigo', label='배달음식비 지출액')
plt.legend()
plt.show()
# Out:
# [8600, 83900, 52800]
# [134300, 127900, 99230]

# %%
import operator

spending = {}

for row in data:
    if row[-1] == '전표매입':
        store, payment = row[-4], int(row[-3])
        if store not in spending.keys():
            spending[store] = payment
        else:
            spending[store] += payment

top10 = sorted(spending.items(), key=operator.itemgetter(1), reverse=True)[:10]
top10_store, top10_payment = [], []

for i in top10:
    top10_store.append(i[0])
    top10_payment.append(i[1])

plt.rc('font', family='Nanum Gothic')
plt.title('10~12월 지출 Top 10')
plt.barh(top10_store, top10_payment, color='b')
plt.show()
print(top10_store)
print(top10_payment)
# Out:
# ['네이버파이낸셜(주)', '스마일페이 (신라면세점)', '(주)현대백화점신촌점', '네이버페이', '(주)우아한형제들', '(주)신세계백화점강남점', '(주)이마트  신촌점', '크로키닷컴', '이유', '쿠팡']
# [1395840, 978035, 415502, 374976, 361430, 333800, 305690, 299610, 285000, 273790]

# %%
total = 0
for row in data:
    if row[-4] != '전표매입':
        total += int(row[-3])
print(total)
# Out:
# 10812585

# %%
s_mon = [0, 0, 0]
for row in data:
     if '백화점' in row[-4]:
         mon, payment = int(row[0].split("-")[1]), int(row[-3])
         idx = int(mon) - 10
         s_mon[idx] += payment
print(s_mon)

plt.rc('font', family='Nanum Gothic')
plt.title('10~12월 백화점 지출액')
plt.bar(['10월', '11월', '12월'], s_mon, color='royalblue') 
plt.show()
# Out:
# [11000, 506200, 232102]
